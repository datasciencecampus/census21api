# %%
import Census21_CACD_Wrapper

# %%
response = Census21_CACD_api_wrapper.result

# %%
Census21_CACD_api_wrapper.print_json(response)
# Out:
# {
#   "observations": [
#     {
#       "dimensions": [
#         {
#           "dimension": "Countries",
#           "dimension_id": "ctry",
#           "option": "England",
#           "option_id": "E92000001"
#         },
#         {
#           "dimension": "General health (6 categories)",
#           "dimension_id": "health_in_general",
#           "option": "Does not apply",
#           "option_id": "-8"
#         },
#         {
#           "dimension": "Highest level of qualification (8 categories)",
#           "dimension_id": "highest_qualification",
#           "option": "Does not apply",
#           "option_id": "-8"
#         }
#       ],
#       "observation": 0
#     },
#     {
#       "dimensions": [
#         {
#           "dimension": "Countries",
#           "dimension_id": "ctry",
#           "option": "England",
#           "option_id": "E92000001"
#         },
#         {
#           "dimension": "General health (6 categories)",
# ...
