# %% [markdown]
# ---
# title: Querying feature item categories
# description: How to query metadata on a particular feature item
# ---

# %% [markdown]
# Some of the features (area types and dimensions) for a population type may be
# unfamiliar or difficult to understand. This guide shows you how to get metadata
# on an item from a feature.
#
# To do this, pass your population type, feature, and item to the
# `CensusAPI.query_categories()` method:

# %%
from census21api import CensusAPI

api = CensusAPI()

population_type = "UR_HH"
feature = "dimensions"
item = "health_in_general"

api.query_categories(population_type, feature, item)
# Out:
#    id             label          dimension population_type
# 0  -8    Does not apply  health_in_general           UR_HH
# 1   1  Very good health  health_in_general           UR_HH
# 2   2       Good health  health_in_general           UR_HH
# 3   3       Fair health  health_in_general           UR_HH
# 4   4        Bad health  health_in_general           UR_HH
# 5   5   Very bad health  health_in_general           UR_HH

# %% [markdown]
# You can use the same method to query category metadata for area types:

# %%
feature = "area-types"
item = "ltla"

api.query_categories(population_type, feature, item)
# Out:
#             id                 label area_type population_type
# 0    E06000001            Hartlepool      ltla           UR_HH
# 1    E06000002         Middlesbrough      ltla           UR_HH
# 2    E06000003  Redcar and Cleveland      ltla           UR_HH
# 3    E06000004      Stockton-on-Tees      ltla           UR_HH
# 4    E06000005            Darlington      ltla           UR_HH
# ..         ...                   ...       ...             ...
# 326  W06000020               Torfaen      ltla           UR_HH
# 327  W06000021         Monmouthshire      ltla           UR_HH
# 328  W06000022               Newport      ltla           UR_HH
# 329  W06000023                 Powys      ltla           UR_HH
# 330  W06000024        Merthyr Tydfil      ltla           UR_HH
#
# [331 rows x 4 columns]
